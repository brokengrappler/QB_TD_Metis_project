# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
sns.set()

from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

import statsmodels.api as sm

# %%
car_avg_df = pd.read_pickle('car_avg_stats_df.pkl')

# %%
def calc_passer_rating(row):
    comp_p = (row['Cmp'] / row['Att'] - .3) * 5
    pyd_p = (row['Pass_Yds'] / row['Att'] - 3) * .25
    td_p = (row['TD'] / row['Att']) * 20
    int_p = 2.375 - (row['Int'] / row['Att']) * 25
    return sum([comp_p, pyd_p, td_p, int_p]) / 6

car_avg_df['YTD_Rating'] = car_avg_df.apply(calc_passer_rating, axis=1)

# %%
car_avg_df['TD%'] = car_avg_df.apply(lambda x: x['TD'] / x['Att'], axis=1)

# %%
car_avg_df['Int%'] = car_avg_df.apply(lambda x: x['Int'] / x['Att'], axis=1)

# %%
car_avg_df.describe(include='all')
# Out:
#                name         Year           G          GS         Win  \
# count           530   530.000000  530.000000  530.000000  530.000000
# unique          106          NaN         NaN         NaN         NaN
# top     Brett Favre          NaN         NaN         NaN         NaN
# freq             19          NaN         NaN         NaN         NaN
# mean            NaN  2006.030189   74.749057   73.892453   43.392453
# std             NaN     8.983656   60.306552   60.229600   39.698685
# min             NaN  1984.000000   11.000000   11.000000    0.000000
# 25%             NaN  1999.000000   29.250000   29.000000   14.000000
# 50%             NaN  2008.000000   58.000000   57.000000   29.000000
# 75%             NaN  2014.000000  107.000000  105.500000   61.750000
# max             NaN  2018.000000  300.000000  298.000000  206.000000
#
#                 TD          Cmp           Att      Pass_Yds         Int  ...  \
# count   530.000000   530.000000    530.000000    530.000000  530.000000  ...
# unique         NaN          NaN           NaN           NaN         NaN  ...
# top            NaN          NaN           NaN           NaN         NaN  ...
# freq           NaN          NaN           NaN           NaN         NaN  ...
# mean    114.107547  1484.473585   2422.518868  17507.377358   68.454717  ...
# std     110.827212  1325.556701   2096.633892  15617.698981   59.421970  ...
# min       3.000000   118.000000    233.000000   1253.000000    3.000000  ...
# 25%      33.000000   488.250000    837.750000   5782.250000   24.000000  ...
# 50%      77.000000  1058.000000   1752.000000  12291.500000   49.000000  ...
# 75%     155.500000  2067.750000   3313.000000  24388.000000   93.750000  ...
# max     530.000000  6571.000000  10165.000000  74216.000000  334.000000  ...
#
#             Att/gm       TD/gm  Pass_Yds/gm      Int/gm       Sk/gm  \
# count   530.000000  530.000000   530.000000  530.000000  530.000000
# unique         NaN         NaN          NaN         NaN         NaN
# top            NaN         NaN          NaN         NaN         NaN
# freq           NaN         NaN          NaN         NaN         NaN
# mean     31.298518    1.389875   221.883020    0.901373    2.079679
# std       3.844746    0.390984    34.650039    0.206351    0.564726
# min      15.533333    0.250000   104.416667    0.250000    0.625000
# 25%      28.768966    1.110278   201.206607    0.767889    1.710383
# 50%      31.926901    1.378788   222.742723    0.895285    2.062500
# 75%      33.872159    1.656250   243.735047    1.061950    2.405565
# max      43.437500    3.125000   318.562500    1.750000    4.500000
#
#         Career W %      Yrs Xp  YTD_Rating         TD%        Int%
# count   530.000000  530.000000  530.000000  530.000000  530.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.555799    5.605660    0.842634    0.044016    0.029068
# std       0.137086    4.280475    0.092770    0.009633    0.007042
# min       0.000000    1.000000    0.528480    0.011236    0.008715
# 25%       0.477273    2.000000    0.776183    0.037302    0.024575
# 50%       0.574074    4.000000    0.846833    0.044455    0.028688
# 75%       0.649050    9.000000    0.902666    0.050489    0.033252
# max       1.000000   19.000000    1.138434    0.086207    0.061433
#
# [11 rows x 23 columns]

# %%
career_ratings = car_avg_df.groupby('name', as_index=False).agg({'YTD_Rating':'mean'})
career_ratings
# Out:
#               name  YTD_Rating
# 0    Aaron Rodgers    1.024250
# 1      Akili Smith    0.528480
# 2       Alex Smith    0.856258
# 3      Andrew Luck    0.848839
# 4      Andy Dalton    0.862714
# ..             ...         ...
# 101    Troy Aikman    0.769248
# 102      Ty Detmer    0.807512
# 103   Tyrod Taylor    0.953573
# 104    Vince Young    0.678560
# 105    Warren Moon    0.766391
#
# [106 rows x 2 columns]

# %%
career_ratings.describe()
# Out:
#        YTD_Rating
# count  106.000000
# mean     0.819858
# std      0.099886
# min      0.528480
# 25%      0.749815
# 50%      0.819422
# 75%      0.878749
# max      1.138434

# %%
plt.hist(career_ratings['YTD_Rating'])
# Out:
# (array([ 1.,  1., 12., 24., 22., 21., 16.,  6.,  2.,  1.]),
#  array([0.52848002, 0.58947541, 0.6504708 , 0.71146619, 0.77246158,
#         0.83345697, 0.89445235, 0.95544774, 1.01644313, 1.07743852,
#         1.13843391]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Used qcut to classify QBs into 3 different tiers

# %%
career_ratings['tier'] = pd.qcut(career_ratings['YTD_Rating'], 3, labels = [3,2,1])

# %%
career_ratings['tier'] = career_ratings['tier'].astype(int)

# %%
car_avg_df.columns
# Out:
# Index(['name', 'Year', 'G', 'GS', 'Win', 'TD', 'Cmp', 'Att', 'Pass_Yds', 'Int',
#        'Sk', 'FY_TD', 'Cmp/gm', 'Att/gm', 'TD/gm', 'Pass_Yds/gm', 'Int/gm',
#        'Sk/gm', 'Career W %', 'Yrs Xp', 'YTD_Rating', 'TD%', 'Int%'],
#       dtype='object')

# %%
data_stats = career_ratings.merge(car_avg_df, on='name')

# %%
data_stats.rename({'YTD_Rating_x':'Car Rating', 'YTD_Rating_y':'YTD_Rating'}, axis=1, inplace=True)

# %%
# A few key 2018 QBs got hurt. Stashing their data here before I drop all NaNs
benched_injured_df = data_stats[(data_stats['FY_TD'].isna()) &
          (data_stats['Year'] == 2018)]

# %%
data_stats.dropna(inplace=True)

# %%
data_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 445 entries, 0 to 528
# Data columns (total 25 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         445 non-null    object
#  1   Car Rating   445 non-null    float64
#  2   tier         445 non-null    int64
#  3   Year         445 non-null    int64
#  4   G            445 non-null    int64
#  5   GS           445 non-null    int64
#  6   Win          445 non-null    int64
#  7   TD           445 non-null    int64
#  8   Cmp          445 non-null    int64
#  9   Att          445 non-null    int64
#  10  Pass_Yds     445 non-null    int64
#  11  Int          445 non-null    int64
#  12  Sk           445 non-null    int64
#  13  FY_TD        445 non-null    float64
#  14  Cmp/gm       445 non-null    float64
#  15  Att/gm       445 non-null    float64
#  16  TD/gm        445 non-null    float64
#  17  Pass_Yds/gm  445 non-null    float64
#  18  Int/gm       445 non-null    float64
#  19  Sk/gm        445 non-null    float64
#  20  Career W %   445 non-null    float64
#  21  Yrs Xp       445 non-null    int64
#  22  YTD_Rating   445 non-null    float64
#  23  TD%          445 non-null    float64
#  24  Int%         445 non-null    float64
# dtypes: float64(12), int64(12), object(1)
# memory usage: 90.4+ KB

# %%
car_avg_stats = ['Year','FY_TD','G','Career W %','Cmp/gm',
                 'Att/gm','TD/gm','TD%','Int%','Pass_Yds/gm','Int/gm',
                 'Sk/gm', 'Yrs Xp', 'tier']

# %%
car_avg_graph_df = data_stats[car_avg_stats]
car_avg_graph_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 445 entries, 0 to 528
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         445 non-null    int64
#  1   FY_TD        445 non-null    float64
#  2   G            445 non-null    int64
#  3   Career W %   445 non-null    float64
#  4   Cmp/gm       445 non-null    float64
#  5   Att/gm       445 non-null    float64
#  6   TD/gm        445 non-null    float64
#  7   TD%          445 non-null    float64
#  8   Int%         445 non-null    float64
#  9   Pass_Yds/gm  445 non-null    float64
#  10  Int/gm       445 non-null    float64
#  11  Sk/gm        445 non-null    float64
#  12  Yrs Xp       445 non-null    int64
#  13  tier         445 non-null    int64
# dtypes: float64(10), int64(4)
# memory usage: 52.1 KB

# %% [markdown]
# ## QB tier analysis

# %%
tier1_graph_df = car_avg_graph_df[car_avg_graph_df['tier'] == 1]
tier2_graph_df =car_avg_graph_df[car_avg_graph_df['tier'] == 2]
tier3_graph_df =car_avg_graph_df[car_avg_graph_df['tier'] == 3]

# %%
tier1_graph_df.describe(include='all')

# %%
tier2_graph_df.describe(include='all')

# %%
tier3_graph_df.describe(include='all')

# %%
fig = plt.figure(figsize=(14,10))
ax1 = sns.heatmap(tier1_graph_df.corr(), cmap='seismic', annot=True, vmin=-1, vmax=1)

# %%
fig = plt.figure(figsize=(14,10))
ax2 = sns.heatmap(tier2_graph_df.corr(), cmap='seismic', annot=True, vmin=-1, vmax=1)

# %%
fig = plt.figure(figsize=(14,10))
ax3 = sns.heatmap(tier3_graph_df.corr(), cmap='seismic', annot=True, vmin=-1, vmax=1)

# %%
sns.pairplot(car_avg_graph_df, height=1.2, aspect=1.5)

# %% [markdown]
# ## Test Set thinking
# 2018 is the test set to compare to 2019 actual performance.

# %%
car_avg_graph_df.head()
# Out:
#    Year  FY_TD   G  Career W %     Cmp/gm     Att/gm     TD/gm       TD%  \
# 0  2008   30.0  16    0.375000  21.312500  33.500000  1.750000  0.052239
# 1  2009   28.0  32    0.531250  21.593750  33.656250  1.812500  0.053853
# 2  2010   45.0  47    0.574468  21.340426  33.021277  1.829787  0.055412
# 3  2011   39.0  62    0.661290  21.709677  33.129032  2.112903  0.063778
# 4  2012   38.0  78    0.666667  22.012821  33.410256  2.179487  0.065234
#
#        Int%  Pass_Yds/gm    Int/gm     Sk/gm  Yrs Xp  tier
# 0  0.024254   252.375000  0.812500  2.125000       1     1
# 1  0.018570   264.750000  0.625000  2.625000       2     1
# 2  0.019974   263.702128  0.659574  2.446809       3     1
# 3  0.018014   274.790323  0.596774  2.435484       4     1
# 4  0.017268   273.487179  0.576923  2.589744       5     1

# %%
test_df_2018 = data_stats[data_stats['Year'] == 2018]

# %%
train_val_df = car_avg_graph_df[car_avg_graph_df['Year'] < 2018].copy()

# %% [markdown]
# # Preliminary feature engineering

# %%
train_val_df.head()
# Out:
#    Year  FY_TD   G  Career W %     Cmp/gm     Att/gm     TD/gm       TD%  \
# 0  2008   30.0  16    0.375000  21.312500  33.500000  1.750000  0.052239
# 1  2009   28.0  32    0.531250  21.593750  33.656250  1.812500  0.053853
# 2  2010   45.0  47    0.574468  21.340426  33.021277  1.829787  0.055412
# 3  2011   39.0  62    0.661290  21.709677  33.129032  2.112903  0.063778
# 4  2012   38.0  78    0.666667  22.012821  33.410256  2.179487  0.065234
#
#        Int%  Pass_Yds/gm    Int/gm     Sk/gm  Yrs Xp  tier
# 0  0.024254   252.375000  0.812500  2.125000       1     1
# 1  0.018570   264.750000  0.625000  2.625000       2     1
# 2  0.019974   263.702128  0.659574  2.446809       3     1
# 3  0.018014   274.790323  0.596774  2.435484       4     1
# 4  0.017268   273.487179  0.576923  2.589744       5     1

# %%
def add_deviation_feature(X, feature, category):
    
    # temp groupby object
    category_gb = X.groupby(category)[feature]
    
    # create columns of category means and standard deviations
    category_mean = category_gb.transform(lambda x: x.mean())
    category_std = category_gb.transform(lambda x: x.std())
    
    # compute stds from category mean for each feature value,
    # add to X as new feature
    deviation_feature = (X[feature] - category_mean) / category_std 
    X[feature + '_Dev_' + category] = deviation_feature
    X[feature + '_Dev_' + category].fillna(value=0, inplace=True)

# %%
add_deviation_feature(train_val_df, 'TD/gm', 'tier')

# %% [markdown]
# # Working with non-test set
#
# ## Create model in sm and perform LR Assumption / residual checks

# %%
# log-transformed FY TD
X = train_val_df.drop(['FY_TD'], axis=1)
y = np.log(train_val_df['FY_TD'])

# %% [markdown]
# ### Note to self, all y has been transformed at this point (including for test set)

# %%
assumption_test_df = train_val_df.copy()

# %%
def stats_model_for_residuals(df, X, y):
    x_for_sm = sm.add_constant(X)
    sm_linear_all = sm.OLS(y, X).fit()
    
    df['predict']=sm_linear_all.predict(X)
    df['resid']= y-df['predict']
    with sns.axes_style('white'):
        plot = df.plot(
            kind='scatter', x='predict', y='resid', alpha=0.5, figsize=(10,6))
    return df

# %%
df_with_residuals = stats_model_for_residuals(train_val_df, X, y)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
plt.figure(figsize=(14,10))
stats.probplot(df_with_residuals['resid'], dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# Residuals appear to be slightly left skewed with minor fluctuations in the error variance.

# %% [markdown]
# # Linear Regression Modeling

# %% [markdown]
# # Cross Validation

# %%
# this is for log transformed only
def MSE_calc(y_val, val_pred):
    return sum((np.exp(y_val) - np.exp(val_pred))**2)/len(y_val)

# %%
def split_and_CV(X, y):
    X, y = np.array(X), np.array(y)
    kf = KFold(n_splits=4, shuffle=True)
    cv_lm_r2 = []
    cv_ridge_r2 = []
    cv_lm_MSE = []
    
    for train_ind, val_ind in kf.split(X,y):
        X_train, y_train = X[train_ind], y[train_ind]
        X_val, y_val = X[val_ind], y[val_ind]
        
        # Linear model
        lr_model = LinearRegression()
        lr_model.fit(X_train, y_train)
        cv_lm_r2.append(lr_model.score(X_val, y_val))
        val_pred = lr_model.predict(X_val)
        MSE_man = MSE_calc(y_val, val_pred)
        cv_lm_MSE.append(MSE_man)

        # Ridge model
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        lm_ridge = Ridge(alpha=.1)
        lm_ridge.fit(X_train_scaled, y_train)
        cv_ridge_r2.append(lm_ridge.score(X_val_scaled, y_val))
    
    print(f'R^2 LM reg: {cv_lm_r2}')
    print(f'LM reg mean cv R^2: {np.mean(cv_lm_r2):.3f} +- {np.std(cv_lm_r2):.3f}')
    print(f'MSE: {cv_lm_MSE}')
    print(f'MSE simple mean: {np.mean(cv_lm_MSE)}\n')

    print(f'R^2 Ridge: {cv_ridge_r2}')
    print(f'LM ridge mean cv R^2: {np.mean(cv_ridge_r2):.3f} +- {np.std(cv_ridge_r2):.3f}\n')

# %%
split_and_CV(X,y)
# Out:
# R^2 LM reg: [0.37032388275510286, 0.2462560921909991, 0.33906058196473476, 0.29415790021053845]
# LM reg mean cv R^2: 0.312 +- 0.047
# MSE: [45.75338015276809, 51.484152816306306, 46.0966991467925, 43.26921907563624]
# MSE simple mean: 46.65086279787578
#
# R^2 Ridge: [0.37082720165444205, 0.24726760139233728, 0.34064223392522397, 0.2962063641840099]
# LM ridge mean cv R^2: 0.314 +- 0.047

# %% [markdown]
# # Feature Engineering

# %%
# polynomial regression

def poly_add(X,y,alpha=1):
    cv_poly_r2 = []
    cv_poly_MSE = []
    cv_ridge_r2 = []
    cv_ridge_MSE = []
    cv_LASSO_r2 = []
    cv_LASSO_MSE = []
    
    # Polynomial factors
    
    X['PY/G^2'] = X['Pass_Yds/gm'] ** 3 + X['Pass_Yds/gm'] ** 2
    X['Cmp/G^2'] = X['Cmp/gm'] ** 3 + X['Cmp/gm'] ** 2
    X['TD/gm^2'] = X['TD/gm'] ** 3 + X['TD/gm'] ** 2
    X['Yrs Xp^2'] = X['Yrs Xp']**2
    
    # Add interaction terms
    X['TD%_/_Int%'] = X['TD%'] / X['Int%']
    
    
    X, y = np.array(X), np.array(y)   
    
    kf = KFold(n_splits=4, shuffle=True)

    for train_ind, val_ind in kf.split(X,y):
        X_train, y_train = X[train_ind], y[train_ind]
        X_val, y_val = X[val_ind], y[val_ind]
        
        # Feature engineered model
        poly_model = LinearRegression()
        poly_model.fit(X_train, y_train)
        cv_poly_r2.append(poly_model.score(X_val, y_val))
        val_pred = poly_model.predict(X_val)
        MSE_man = MSE_calc(y_val, val_pred)
        cv_poly_MSE.append(MSE_man)
        
        #### Regularization Section ####
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)

        # Ridge
#         lm_ridge = Ridge(alpha=alpha)
#         lm_ridge.fit(X_train_scaled, y_train)
#         cv_ridge_r2.append(lm_ridge.score(X_val_scaled, y_val))
#         val_pred = lm_ridge.predict(X_val_scaled)
#         MSE_man = MSE_calc(y_val, val_pred)
#         cv_ridge_MSE.append(MSE_man)
        
        # LASSO
        lasso_model = Lasso(alpha=alpha)
        lasso_model.fit(X_train_scaled, y_train)
        cv_LASSO_r2.append(lasso_model.score(X_val_scaled, y_val))
        val_pred = lasso_model.predict(X_val_scaled)
        MSE_man = MSE_calc(y_val, val_pred)
        cv_LASSO_MSE.append(MSE_man)
        
    print(f'R^2 Poly: {cv_poly_r2}')
    print(f'Poly mean cv R^2: {np.mean(cv_poly_r2):.3f} +- {np.std(cv_poly_r2):.3f}')
    print(f'Poly MSE: {cv_poly_MSE}')
    print(f'Poly MSE: {np.mean(cv_poly_MSE):.3f} +- {np.std(cv_poly_MSE):.3f}\n')
 
#     print(f'R^2 Ridge: {cv_ridge_r2}')
#     print(f'Poly ridge mean cv R^2: {np.mean(cv_ridge_r2):.3f} +- {np.std(cv_ridge_r2):.3f}')
#     print(f'Poly ridge MSE: {cv_ridge_MSE}')
#     print(f'Poly MSE: {np.mean(cv_ridge_MSE):.3f} +- {np.std(cv_ridge_MSE):.3f}\n')

    print(f'R^2 LASSO: {cv_LASSO_r2}')
    print(f'Poly LASSO mean cv R^2: {np.mean(cv_LASSO_r2):.3f} +- {np.std(cv_LASSO_r2):.3f}')
    print(f'Poly LASSO MSE: {cv_LASSO_MSE}')
    print(f'Poly MSE: {np.mean(cv_LASSO_MSE):.3f} +- {np.std(cv_LASSO_MSE):.3f}')

# %%
poly_add(X,y,.001)
# Out:
# R^2 Poly: [0.3133807721472155, 0.2589057244288685, 0.3501786124335764, 0.34970177228144317]
# Poly mean cv R^2: 0.318 +- 0.037
# Poly MSE: [36.96045874550221, 45.18482524915212, 52.57611948780705, 49.4558774489946]
# Poly MSE: 46.044 +- 5.864
#
# R^2 LASSO: [0.34041025387681045, 0.3283722609662292, 0.36148019902815365, 0.372801130345932]
# Poly LASSO mean cv R^2: 0.351 +- 0.017
# Poly LASSO MSE: [35.99892746718593, 40.16717497726673, 51.69837165711501, 47.972565040278944]
# Poly MSE: 43.959 +- 6.200

# %%
def Lasso_with_CV(X,y):
    lasso_model_score = []    
    # Polynomial factors
    
    X['PY/G^2'] = X['Pass_Yds/gm'] ** 3 + X['Pass_Yds/gm'] ** 2
    X['Cmp/G^2'] = X['Cmp/gm'] ** 3 + X['Cmp/gm'] ** 2
    X['TD/gm^2'] = X['TD/gm'] ** 3 + X['TD/gm'] ** 2
    X['Yrs Xp^2'] = X['Yrs Xp']**2
    
    # Add interaction terms
    X['TD%_/_Int%'] = X['TD%'] / X['Int%']
    
    X_train, X_val, y_train, y_val = train_test_split(X, y)
    
    scaler = StandardScaler()
    scaler.fit(X_train.values)
    
    X_tr_scaled = scaler.transform(X_train.values)
    X_val_scaled = scaler.transform(X_val.values)
    
    alphavec = 10**np.linspace(-2,2,200)
    lasso_model = LassoCV(alphas=alphavec, cv=4)
    lasso_model.fit(X_tr_scaled, y_train)
    lasso_model_score.append(lasso_model.score(X_val_scaled, y_val))
    val_pred = lasso_model.predict(X_val_scaled)
    print(lasso_model.alpha_)
    print(MSE_calc(y_val, val_pred))
    print(lasso_model_score)

# %%
Lasso_with_CV(X,y)
# Out:
# 0.010473708979594498
# 61.620977210386506
# [0.38967093692381716]

# %%
def Ridge_with_CV(X,y):
    Ridge_model_score = []  
    # Polynomial factors
    X['PY/G^2'] = X['Pass_Yds/gm'] ** 3 + X['Pass_Yds/gm'] ** 2
    X['Cmp/G^2'] = X['Cmp/gm'] ** 3 + X['Cmp/gm'] ** 2
    X['TD/gm^2'] = X['TD/gm'] ** 3 + X['TD/gm'] ** 2
    
    # Add interaction terms
    X['TD%_/_Int%'] = X['TD%'] / X['Int%']
    
    # split, scale, transform
    X_train, X_val, y_train, y_val = train_test_split(X, y)
    scaler = StandardScaler()
    scaler.fit(X_train.values)
    X_tr_scaled = scaler.transform(X_train.values)
    X_val_scaled = scaler.transform(X_val.values)
    
    alphavec = 10**np.linspace(-2,2,200)
    ridge_model = RidgeCV(alphas=alphavec, cv=4)
    ridge_model.fit(X_tr_scaled, y_train)
    val_pred = ridge_model.predict(X_val_scaled)
    Ridge_model_score.append(ridge_model.score(X_val_scaled, y_val))
    print(ridge_model.alpha_)
    print(MSE_calc(y_val, val_pred))
    print(ridge_model.score)

# %%
Ridge_with_CV(X,y)
# Out:
# 60.10276782070382
# 40.949676729262684
# <bound method RegressorMixin.score of RidgeCV(alphas=array([1.00000000e-02, 1.04737090e-02, 1.09698580e-02, 1.14895100e-02,
#        1.20337784e-02, 1.26038293e-02, 1.32008840e-02, 1.38262217e-02,
#        1.44811823e-02, 1.51671689e-02, 1.58856513e-02, 1.66381689e-02,
#        1.74263339e-02, 1.82518349e-02, 1.91164408e-02, 2.00220037e-02,
#        2.09704640e-02, 2.19638537e-02, 2.30043012e-02, 2.40940356e-02,
#        2.52353917e-02, 2.64308149e-0...
#        3.44896226e+01, 3.61234270e+01, 3.78346262e+01, 3.96268864e+01,
#        4.15040476e+01, 4.34701316e+01, 4.55293507e+01, 4.76861170e+01,
#        4.99450512e+01, 5.23109931e+01, 5.47890118e+01, 5.73844165e+01,
#        6.01027678e+01, 6.29498899e+01, 6.59318827e+01, 6.90551352e+01,
#        7.23263390e+01, 7.57525026e+01, 7.93409667e+01, 8.30994195e+01,
#        8.70359136e+01, 9.11588830e+01, 9.54771611e+01, 1.00000000e+02]),
#         cv=4)>

# %% [markdown]
# # Testing the model on validation (2017) to get a feel

# %%
X.isna().sum()
# Out:
# Year              0
# G                 0
# Career W %        0
# Cmp/gm            0
# Att/gm            0
# TD/gm             0
# TD%               0
# Int%              0
# Pass_Yds/gm       0
# Int/gm            0
# Sk/gm             0
# Yrs Xp            0
# tier              0
# TD/gm_Dev_tier    0
# PY/G^2            0
# Cmp/G^2           0
# TD/gm^2           0
# Yrs Xp^2          0
# TD%_/_Int%        0
# dtype: int64

# %%
y.isna().sum()
# Out:
# 0

# %%
test_input = data_stats.copy()

# %%
add_deviation_feature(test_input, 'TD/gm', 'tier' )

# %%
def test_model(X_train, y, X_test, alpha=0.01):
    
    X_train['PY/G^2'] = X_train['Pass_Yds/gm'] ** 3 + X_train['Pass_Yds/gm'] ** 2
    X_train['Cmp/G^2'] = X_train['Cmp/gm'] ** 3 + X_train['Cmp/gm'] ** 2
    X_train['TD/gm^2'] = X_train['TD/gm'] ** 3 + X_train['TD/gm'] ** 2
    X_train['Yrs Xp^2'] = X_train['Yrs Xp']**2    
    X_train['TD%_/_Int%'] = X_train['TD%'] / X_train['Int%']

    X_test['PY/G^2'] = X_test['Pass_Yds/gm'] ** 3 + X_test['Pass_Yds/gm'] ** 2
    X_test['Cmp/G^2'] = X_test['Cmp/gm'] ** 3 + X_test['Cmp/gm'] ** 2
    X_test['TD/gm^2'] = X_test['TD/gm'] ** 3 + X_test['TD/gm'] ** 2
    X_test['Yrs Xp^2'] = X_test['Yrs Xp']**2
    X_test['TD%_/_Int%'] = X_test['TD%'] / X_test['Int%']
    
    scaler = StandardScaler()
    X_tr_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
#     poly_model = LinearRegression()
#     poly_model.fit(X_train, y)
#     predictions = poly_model.predict(X_test)
    
    # LASSO
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_tr_scaled, y)
    ln_predictions = lasso_model.predict(X_test_scaled)
    coefs = dict(zip(X_test.columns,lasso_model.coef_))
    for key, val in coefs.items():
        print(key,val)
    return ln_predictions

# %%
sel_features = ['name','Year', 'FY_TD', 'G', 'Career W %', 'Cmp/gm', 'Att/gm', 'TD/gm', 'TD%',
       'Int%', 'Pass_Yds/gm', 'Int/gm', 'Sk/gm', 'Yrs Xp', 'tier', 'TD/gm_Dev_tier']

# %%
# need to filter features
test_input = test_input[sel_features]

# %%
test_input = test_input[test_input['Year'] == 2017]

# %%
test_input
# Out:
#                    name  Year  FY_TD    G  Career W %     Cmp/gm     Att/gm  \
# 28          Andy Dalton  2017   21.0  109    0.577982  20.339450  32.623853
# 44   Ben Roethlisberger  2017   34.0  200    0.681818  20.820000  32.465000
# 50        Blake Bortles  2017   13.0   62    0.344262  21.258065  35.951613
# 80           Cam Newton  2017   24.0  109    0.574074  18.357798  31.376147
# 93         Carson Wentz  2017   21.0   29    0.620690  22.206897  36.103448
# 95          Case Keenum  2017   18.0   15    0.785714  21.666667  32.066667
# 115        Dak Prescott  2017   22.0   32    0.687500  19.343750  29.656250
# 144          Derek Carr  2017   19.0   62    0.451613  22.225806  36.241935
# 172          Drew Brees  2017   32.0  248    0.572581  25.028226  37.366935
# 186         Eli Manning  2017   21.0  207    0.531401  20.913043  34.777778
# 195     Jacoby Brissett  2017   18.0   16    0.266667  17.250000  29.312500
# 199      Jameis Winston  2017   33.0   45    0.400000  20.866667  34.311111
# 200          Jared Goff  2017   32.0   15    0.733333  19.733333  31.800000
# 279         Josh McCown  2017   18.0   76    0.324324  18.000000  29.789474
# 295        Kirk Cousins  2017   30.0   48    0.500000  23.583333  35.187500
# 309      Marcus Mariota  2017   11.0   42    0.476190  18.738095  30.333333
# 337           Matt Ryan  2017   35.0  158    0.601266  22.974684  35.398734
# 350    Matthew Stafford  2017   21.0  112    0.508929  24.526786  39.080357
# 361   Mitchell Trubisky  2017   24.0   12    0.333333  16.333333  27.500000
# 392       Philip Rivers  2017   32.0  192    0.552083  21.635417  33.656250
# 425      Russell Wilson  2017   35.0   96    0.677083  18.906250  29.520833
# 484           Tom Brady  2017   29.0  251    0.780000  22.394422  35.023904
#
#         TD/gm       TD%      Int%  Pass_Yds/gm    Int/gm     Sk/gm  Yrs Xp  \
# 28   1.532110  0.046963  0.026153   234.256881  0.853211  2.018349       7
# 44   1.645000  0.050670  0.026798   255.325000  0.870000  2.385000      14
# 50   1.451613  0.040377  0.028712   240.774194  1.032258  2.645161       4
# 80   1.449541  0.046199  0.027485   230.036697  0.862385  2.348624       7
# 93   1.689655  0.046800  0.020057   244.068966  0.724138  2.103448       2
# 95   1.466667  0.045738  0.014553   236.466667  0.466667  1.466667       1
# 115  1.406250  0.047418  0.017914   218.468750  0.531250  1.781250       2
# 144  1.661290  0.045839  0.019582   236.935484  0.709677  1.467742       4
# 172  1.963710  0.052552  0.024603   283.161290  0.919355  1.516129      16
# 186  1.608696  0.046256  0.030421   244.632850  1.057971  1.671498      13
# 195  0.812500  0.027719  0.014925   193.625000  0.437500  3.250000       1
# 199  1.533333  0.044689  0.028497   258.577778  0.977778  2.111111       3
# 200  1.866667  0.058700  0.014675   253.600000  0.466667  1.666667       1
# 279  1.052632  0.035336  0.029152   201.131579  0.868421  2.789474      14
# 295  1.687500  0.047957  0.021314   274.500000  0.750000  1.875000       3
# 309  1.380952  0.045526  0.026688   225.619048  0.809524  2.095238       3
# 337  1.645570  0.046487  0.022528   264.531646  0.797468  1.765823      10
# 350  1.758929  0.045008  0.022161   285.241071  0.866071  2.330357       7
# 361  0.583333  0.021212  0.021212   182.750000  0.583333  2.583333       1
# 392  1.776042  0.052770  0.025534   261.458333  0.859375  1.958333      12
# 425  1.677083  0.056810  0.019760   231.000000  0.583333  2.583333       6
# 484  1.944223  0.055511  0.018200   263.254980  0.637450  1.800797      17
#
#      tier  TD/gm_Dev_tier
# 28      1       -0.452034
# 44      1       -0.106740
# 50      2        0.696979
# 80      1       -0.704586
# 93      1        0.029845
# 95      1       -0.652205
# 115     1       -0.837000
# 144     2        1.413606
# 172     1        0.868090
# 186     2        1.233850
# 195     2       -1.487355
# 199     2        0.976280
# 200     1        0.571267
# 279     3       -0.039821
# 295     1        0.023253
# 309     1       -0.914377
# 337     1       -0.104998
# 350     1        0.241731
# 361     2       -2.270591
# 392     1        0.294074
# 425     1       -0.008608
# 484     1        0.808487

# %%
test_model = test_model(X,y,test_input.drop(['name','FY_TD'], axis=1))
# Out:
# Year 0.019173736611318003
# G 0.0
# Career W % 0.02508149900696374
# Cmp/gm 0.0924436788549634
# Att/gm 0.0
# TD/gm 0.01734462122733005
# TD% 0.01328357380868737
# Int% 0.0
# Pass_Yds/gm 0.021588726849825046
# Int/gm 0.013456874313897084
# Sk/gm 0.0028478655677063513
# Yrs Xp 0.011579649805023214
# tier -0.08354093647311601
# TD/gm_Dev_tier 0.0
# PY/G^2 0.0
# Cmp/G^2 0.0
# TD/gm^2 0.0
# Yrs Xp^2 -0.0
# TD%_/_Int% -0.0

# %%
test_model
# Out:
# array([3.23670752, 3.31795333, 3.11028445, 3.16698735, 3.29548703,
#        3.26909481, 3.17316598, 3.14886188, 3.47260091, 3.17392681,
#        2.84583381, 3.11990408, 3.24555113, 2.85947752, 3.34184705,
#        3.13819578, 3.35312886, 3.40106723, 2.80828301, 3.32455888,
#        3.20956274, 3.40248656])

# %%
test_predict=test_input[['name','FY_TD']]

# %%
test_predict['Pred'] = np.exp(test_model)
# Out:
# <ipython-input-61-54afd85870e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_predict['Pred'] = np.exp(test_model)

# %%
test_predict
# Out:
#                    name  FY_TD       Pred
# 28          Andy Dalton   21.0  25.449791
# 44   Ben Roethlisberger   34.0  27.603797
# 50        Blake Bortles   13.0  22.427423
# 80           Cam Newton   24.0  23.735869
# 93         Carson Wentz   21.0  26.990556
# 95          Case Keenum   18.0  26.287533
# 115        Dak Prescott   22.0  23.882978
# 144          Derek Carr   19.0  23.309521
# 172          Drew Brees   32.0  32.220436
# 186         Eli Manning   21.0  23.901156
# 195     Jacoby Brissett   18.0  17.215908
# 199      Jameis Winston   33.0  22.644207
# 200          Jared Goff   32.0  25.675857
# 279         Josh McCown   18.0  17.452406
# 295        Kirk Cousins   30.0  28.271297
# 309      Marcus Mariota   11.0  23.062220
# 337           Matt Ryan   35.0  28.592054
# 350    Matthew Stafford   21.0  29.996096
# 361   Mitchell Trubisky   24.0  16.581424
# 392       Philip Rivers   32.0  27.786739
# 425      Russell Wilson   35.0  24.768254
# 484           Tom Brady   29.0  30.038700

# %%
test_predict['residual'] = abs(test_predict['FY_TD'] - test_predict['Pred'])
# Out:
# <ipython-input-63-37fa2b0bfaba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_predict['residual'] = abs(test_predict['FY_TD'] - test_predict['Pred'])

# %%
np.sum(test_predict['residual']) / len(test_predict['residual'])
# Out:
# 5.192663564864725

# %% [markdown]
# # Loading the test data and running predictions on test set

# %%
qb_set_2018 = test_df_2018.append(benched_injured_df)

# %%
add_deviation_feature(qb_set_2018, 'TD/gm', 'tier' )

# %%
qb_set_2018 = qb_set_2018[sel_features]

# %%
def final_model(X_train, y, X_test, alpha=0.01):
    
    X_train['PY/G^2'] = X_train['Pass_Yds/gm'] ** 3 + X_train['Pass_Yds/gm'] ** 2
    X_train['Cmp/G^2'] = X_train['Cmp/gm'] ** 3 + X_train['Cmp/gm'] ** 2
    X_train['TD/gm^2'] = X_train['TD/gm'] ** 3 + X_train['TD/gm'] ** 2
    X_train['Yrs Xp^2'] = X_train['Yrs Xp']**2    
    X_train['TD%_/_Int%'] = X_train['TD%'] / X_train['Int%']

    X_test['PY/G^2'] = X_test['Pass_Yds/gm'] ** 3 + X_test['Pass_Yds/gm'] ** 2
    X_test['Cmp/G^2'] = X_test['Cmp/gm'] ** 3 + X_test['Cmp/gm'] ** 2
    X_test['TD/gm^2'] = X_test['TD/gm'] ** 3 + X_test['TD/gm'] ** 2
    X_test['Yrs Xp^2'] = X_test['Yrs Xp']**2
    X_test['TD%_/_Int%'] = X_test['TD%'] / X_test['Int%']
    
    scaler = StandardScaler()
    X_tr_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # LASSO
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_tr_scaled, y)
    ln_predictions = lasso_model.predict(X_test_scaled)
    print(lasso_model.coef_)
    
    return ln_predictions

# %%
test_results = final_model(X,y,qb_set_2018.drop(['name','FY_TD'], axis=1))
# Out:
# [ 0.01917374  0.          0.0250815   0.09244368  0.          0.01734462
#   0.01328357  0.          0.02158873  0.01345687  0.00284787  0.01157965
#  -0.08354094  0.          0.          0.          0.         -0.
#  -0.        ]

# %%
results_df = qb_set_2018[['name','FY_TD']]

# %%
results_df['Pred'] = np.round_(np.exp(test_results), 0)
# Out:
# <ipython-input-72-3155d9442b42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df['Pred'] = np.round_(np.exp(test_results), 0)

# %%
results_df['Residual'] = results_df['Pred'] - results_df['FY_TD']
# Out:
# <ipython-input-73-6a44ad474c65>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df['Residual'] = results_df['Pred'] - results_df['FY_TD']

# %%
results_df['% var'] = (results_df['Residual'] / results_df['FY_TD'])
# Out:
# <ipython-input-74-80cc3845bb04>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results_df['% var'] = (results_df['Residual'] / results_df['FY_TD'])

# %%
results_df.sort_values(by='FY_TD', ascending=False)
# Out:
#                    name  FY_TD  Pred  Residual     % var
# 426      Russell Wilson   31.0  25.0      -6.0 -0.193548
# 116        Dak Prescott   30.0  25.0      -5.0 -0.166667
# 94         Carson Wentz   27.0  28.0       1.0  0.037037
# 173          Drew Brees   27.0  32.0       5.0  0.185185
# 8         Aaron Rodgers   26.0  29.0       3.0  0.115385
# 296        Kirk Cousins   26.0  29.0       3.0  0.115385
# 364     Patrick Mahomes   26.0  35.0       9.0  0.346154
# 146      Deshaun Watson   26.0  27.0       1.0  0.038462
# 338           Matt Ryan   26.0  29.0       3.0  0.115385
# 485           Tom Brady   24.0  30.0       6.0  0.250000
# 393       Philip Rivers   23.0  28.0       5.0  0.217391
# 201          Jared Goff   22.0  28.0       6.0  0.272727
# 30       Baker Mayfield   22.0  28.0       6.0  0.272727
# 145          Derek Carr   21.0  23.0       2.0  0.095238
# 271          Josh Allen   20.0  15.0      -5.0 -0.250000
# 444         Sam Darnold   19.0  20.0       1.0  0.052632
# 362   Mitchell Trubisky   17.0  20.0       3.0  0.176471
# 29          Andy Dalton   16.0  26.0      10.0  0.625000
# 21          Andrew Luck    NaN  27.0       NaN       NaN
# 45   Ben Roethlisberger    NaN  28.0       NaN       NaN
# 51        Blake Bortles    NaN  22.0       NaN       NaN
# 81           Cam Newton    NaN  24.0       NaN       NaN
# 96          Case Keenum    NaN  26.0       NaN       NaN
# 187         Eli Manning    NaN  24.0       NaN       NaN
# 281          Josh Rosen    NaN  15.0       NaN       NaN
# 310      Marcus Mariota    NaN  22.0       NaN       NaN
# 351    Matthew Stafford    NaN  30.0       NaN       NaN
# 439      Ryan Tannehill    NaN  23.0       NaN       NaN

# %%
results_df['Residual'].apply(lambda x: x**2).sum() / len(results_df['Residual'])
# Out:
# 16.714285714285715

# %% [markdown]
# # And for my 2019 Predictions

# %%
qb_df_raw_2019 = pd.read_pickle('2019_data_for_pred.pkl')

# %%
# start_list_2019 = ['Josh Allen', 'Ryan Fitzpatrick', 'Cam Newton', 'Sam Darnold', 'Lamar Jackson',
#                    'Baker Mayfield', 'Ben Roethlisberger', 'Deshaun Watson', 'Philip Rivers', 'Ryan Tannehill',
#                    'Patrick Mahomes', 'Derek Carr', 'Tyrod Taylor', 'Dak Prescott', 'Carson Wentz', 'Dwayne Haskins',
#                    'Mitchell Trubisky', 'Matthew Stafford', 'Aaron Rodgers', 'Kirk Cousins', 'Matt Ryan', 'Drew Brees',
#                    'Tom Brady', 'Kyler Murray', 'Jared Goff', 'Jimmy Garoppolo', 'Russell Wilson']

# %%
qb_df_raw_2019['TD%'] = qb_df_raw_2019.apply(lambda x: x['TD'] / x['Att'], axis=1)
qb_df_raw_2019['Int%'] = qb_df_raw_2019.apply(lambda x: x['Int'] / x['Att'], axis=1)

# %%
qb_2019_data = career_ratings.merge(qb_df_raw_2019, on='name', how='right')

# %%
# Manually filling in data for Jimmy G and Lamar
qb_2019_data['YTD_Rating'] = qb_2019_data.apply(calc_passer_rating, axis=1)
qb_2019_data.loc[21,'tier'] = 1
qb_2019_data.loc[22,'tier'] = 1

# %%
add_deviation_feature(qb_2019_data, 'TD/gm', 'tier')

# %%
qb_set_2019 = qb_2019_data[sel_features]

# %%
qb_set_2019.head()
# Out:
#              name  Year  FY_TD    G  Career W %     Cmp/gm     Att/gm  \
# 0   Aaron Rodgers  2019    NaN  158    0.651899  22.348101  34.645570
# 1     Andy Dalton  2019    NaN  133    0.526316  20.729323  33.451128
# 2  Baker Mayfield  2019    NaN   30    0.413793  20.900000  34.000000
# 3    Carson Wentz  2019    NaN   56    0.571429  23.410714  36.696429
# 4    Dak Prescott  2019    NaN   64    0.625000  21.296875  32.359375
#
#       TD/gm       TD%      Int%  Pass_Yds/gm    Int/gm     Sk/gm  Yrs Xp  \
# 0  2.088608  0.060285  0.012970   268.392405  0.449367  2.506329      12
# 1  1.533835  0.045853  0.026523   237.548872  0.887218  2.090226       9
# 2  1.633333  0.048039  0.034314   251.733333  1.166667  2.166667       2
# 3  1.732143  0.047202  0.017032   253.410714  0.625000  2.303571       4
# 4  1.515625  0.046837  0.017383   246.531250  0.562500  2.125000       4
#
#    tier  TD/gm_Dev_tier
# 0   1.0        0.868861
# 1   1.0       -1.062602
# 2   1.0       -0.716194
# 3   1.0       -0.372185
# 4   1.0       -1.126000

# %%
qb_set_2019.drop(['name','FY_TD'], axis=1).head()
# Out:
#    Year    G  Career W %     Cmp/gm     Att/gm     TD/gm       TD%      Int%  \
# 0  2019  158    0.651899  22.348101  34.645570  2.088608  0.060285  0.012970
# 1  2019  133    0.526316  20.729323  33.451128  1.533835  0.045853  0.026523
# 2  2019   30    0.413793  20.900000  34.000000  1.633333  0.048039  0.034314
# 3  2019   56    0.571429  23.410714  36.696429  1.732143  0.047202  0.017032
# 4  2019   64    0.625000  21.296875  32.359375  1.515625  0.046837  0.017383
#
#    Pass_Yds/gm    Int/gm     Sk/gm  Yrs Xp  tier  TD/gm_Dev_tier
# 0   268.392405  0.449367  2.506329      12   1.0        0.868861
# 1   237.548872  0.887218  2.090226       9   1.0       -1.062602
# 2   251.733333  1.166667  2.166667       2   1.0       -0.716194
# 3   253.410714  0.625000  2.303571       4   1.0       -0.372185
# 4   246.531250  0.562500  2.125000       4   1.0       -1.126000

# %%
predict_2019 = final_model(X,y,qb_set_2019.drop(['name','FY_TD'], axis=1))
# Out:
# [ 0.01917374  0.          0.0250815   0.09244368  0.          0.01734462
#   0.01328357  0.          0.02158873  0.01345687  0.00284787  0.01157965
#  -0.08354094  0.          0.          0.          0.         -0.
#  -0.        ]

# %%
results_2019 = pd.DataFrame(qb_set_2019['name'])

# %%
results_2019['2020 Prediction'] = np.round_(np.exp(predict_2019), 0)

# %%
results_2019.sort_values(by='2020 Prediction',ascending=False)
# Out:
#                  name  2020 Prediction
# 7          Drew Brees             33.0
# 15    Patrick Mahomes             32.0
# 20          Tom Brady             30.0
# 13          Matt Ryan             30.0
# 0       Aaron Rodgers             29.0
# 12       Kirk Cousins             29.0
# 10         Jared Goff             29.0
# 3        Carson Wentz             28.0
# 16      Philip Rivers             28.0
# 6      Deshaun Watson             28.0
# 21    Jimmy Garoppolo             27.0
# 22      Lamar Jackson             26.0
# 1         Andy Dalton             26.0
# 4        Dak Prescott             26.0
# 2      Baker Mayfield             26.0
# 17     Russell Wilson             25.0
# 9      Jameis Winston             24.0
# 5          Derek Carr             23.0
# 14  Mitchell Trubisky             21.0
# 18   Ryan Fitzpatrick             21.0
# 19        Sam Darnold             21.0
# 8     Jacoby Brissett             18.0
# 11         Josh Allen             16.0

# %% [markdown]
# # Compare the results and figure out confidence interval

# %%
def get_prediction_interval(prediction, y_test, test_predictions, pi=.95):
    '''
    Get a prediction interval for a linear regression.
    
    INPUTS: 
        - Single prediction, 
        - y_test
        - All test set predictions,
        - Prediction interval threshold (default = .95) 
    OUTPUT: 
        - Prediction interval for single prediction
    '''
    
    #get standard deviation of y_test
    sum_errs = np.sum((y_test - test_predictions)**2)
    stdev = np.sqrt(1 / (len(y_test) - 2) * sum_errs)
#get interval from standard deviation
    one_minus_pi = 1 - pi
    ppf_lookup = 1 - (one_minus_pi / 2)
    z_score = stats.norm.ppf(ppf_lookup)
    interval = z_score * stdev
#generate prediction interval lower and upper bound
    lower, upper = prediction - interval, prediction + interval
    return lower, prediction, upper
get_prediction_interval(predictions[0], y_test, predictions)
OUTPUT: (19.24072024369257, 28.996723619824934, 38.752726995957296

# %%
def lasso_test(X_train, y, X_test, alpha=0.01):
    
    X_train['PY/G^2'] = X_train['Pass_Yds/gm'] ** 3 + X_train['Pass_Yds/gm'] ** 2
    X_train['Cmp/G^2'] = X_train['Cmp/gm'] ** 3 + X_train['Cmp/gm'] ** 2
    X_train['TD/gm^2'] = X_train['TD/gm'] ** 3 + X_train['TD/gm'] ** 2
    X_train['TD%_/_Int%'] = X_train['TD%'] / X_train['Int%']

    X_test['PY/G^2'] = X_test['Pass_Yds/gm'] ** 3 + X_test['Pass_Yds/gm'] ** 2
    X_test['Cmp/G^2'] = X_test['Cmp/gm'] ** 3 + X_test['Cmp/gm'] ** 2
    X_test['TD/gm^2'] = X_test['TD/gm'] ** 3 + X_test['TD/gm'] ** 2
    X_test['TD%_/_Int%'] = X_test['TD%'] / X_test['Int%']
    
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
 
    # LASSO
    lasso_model = Lasso(alpha=alpha)
    lasso_model.fit(X_scaled, y)
    predictions = lasso_model.predict(X_test_scaled)
    print(lasso_model.coef_)
    return predictions
